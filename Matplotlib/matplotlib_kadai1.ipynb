# %% [markdown]
# # 課題 1
#
# dummy_covid_data.csv を読み込み以下のようなグラフを表示しましょう。
# ![matplotlib_kadai1.png](matplotlib_kadai1.png)

# %%
# importは自由に追加してよい
import re
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import ScalarFormatter

df = pd.read_csv(filepath_or_buffer="dummy_covid_data.csv", encoding="utf-8", sep=",")
df
# Out:
#       検査実施期間  英国で発見した変異株陽性者数  南アフリカで発見した変異株陽性者数  ブラジルで発見した変異株陽性者数  その他陽性者数
# 0  3/15-3/21              37                  3                16     1670
# 1  3/22-3/28             220                  6                25     1764
# 2   3/29-4/4             605                 15                52     1990

# %%
# 課題1回答実装例

fp = FontProperties(fname=r'C:\WINDOWS\Fonts\meiryob.ttc', size=10)
fig = plt.figure(figsize=(6, 3), dpi=100)

# グラフの装飾
plt.title('陽性者数推移', fontproperties=fp) # タイトル
plt.xlabel('検査実施期間', fontproperties=fp) # x軸ラベル
plt.ylabel('人', fontproperties=fp) # y軸ラベル

# グラフを描画
#---------------------------------
# ここに実装




plt.legend(loc="lower right", prop=fp) # 凡例表示
# Out:
# No handles with labels found to put in legend.
